# %%
# Seaborn 配置开发环境
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# seaborn
import seaborn as sns

# 忽略警告信息
import warnings
warnings.filterwarnings('ignore')

print("成功建立开发环境")
# Out:
# 成功建立开发环境

# %%
# Seaborn 内置数据集
# 来源: https://github.com/mwaskom/seaborn-data
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# pandas绘制boxplot
iris.plot.box()
# Out:
# <AxesSubplot:>

# %%
# seaborn 绘制boxplot
sns.boxplot(data=iris)
# Out:
# <AxesSubplot:>

# %%
# pandas 对比不同类petal_length分布情况
iris[['species', 'petal_length']].boxplot(by='species')
# Out:
# <AxesSubplot:title={'center':'petal_length'}, xlabel='[species]'>

# %%
# seaborn 对比不同类petal_length分布情况
sns.boxplot(data=iris, x='species', y='petal_length')
sns.swarmplot(data=iris, x='species', y='petal_length', color='red')
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
# tips 小费数据集
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# totoal_bill: 账单总额
# tip: 小费
# sex: 性别
# smoker: 是否抽烟
# bay: 星期几
# time: 用餐时间 午餐 lunch, 晚餐 dinner
# size: 几人用餐

# %%
# 条形图
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# 一行代码查看所有数据分布情况及其关系
sns.relplot(x='total_bill', y='tip', col='time', row='day', hue='smoker', style='sex', size='size', height=3, data=tips)

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set() # 缺省颜色样式配置
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
### 设置图表背景
sns.set_style('whitegrid') # white, dark, whitegrid, darkgrid, ticks
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day', y='total_bill', data=tips)
# 设置是否显示边框
# left: True 隐藏左侧边线
# bottom: True 隐藏底部边线
# top/right: 缺省 True
sns.despine(left=True, bottom=True)

# %%
# 上下文(场景)设置: paper: 0.8, notebook: 1.0, talk: 2.5左右, poster: 5.0左右
sns.set_context('talk')
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# font_scale: 设置字体放大,缩小
# rc={'lines.linewidth':3} : 设置线粗细程度
sns.set_context('notebook', font_scale=1.5, rc={'lines.linewidth':3})
sns.barplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# 色彩配置
sns.color_palette()
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411),
#  (0.5490196078431373, 0.5490196078431373, 0.5490196078431373),
#  (0.8, 0.7254901960784313, 0.4549019607843137),
#  (0.39215686274509803, 0.7098039215686275, 0.803921568627451)]

# %%
# 绘制调色板
sns.palplot(sns.color_palette()) # 缺省配置

# %%
# https://matplotlib.org/examples/color/colormaps_reference.html
# seaborn 使用 matplotlib 色图配置
sns.palplot(sns.color_palette('tab20'))

# %%
# palette: 获取色图配置
sns.set_context('notebook')
sns.barplot(x='size', y='total_bill', data=tips, palette=sns.color_palette('tab20'))
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
sns.barplot(x='size', y='total_bill', data=tips, palette=sns.color_palette('tab20')[0::2])
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
# 自定义色彩
# rgb标准色彩名称网址: https://xkcd.com/color/rgb/
colors = ["red", "green", "blue", "yellow", "#34495e", "#2ecc71"]
sns.barplot(x='size', y='total_bill', data=tips, palette=sns.color_palette(colors))
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
color='#3498db'
# 自己生成色图
# sns.barplot(x='size', y='total_bill', data=tips, palette=sns.light_palette(color)) # 由白色渐深
sns.barplot(x='size', y='total_bill', data=tips, palette=sns.dark_palette(color)) # 由黑色渐浅
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %%
# 动态配置调色工具
# sns.choose_cubehelix_palette() # 返回本身的数值
sns.choose_cubehelix_palette(as_cmap=True)
# Out:
# interactive(children=(IntSlider(value=9, description='n_colors', max=16, min=2), FloatSlider(value=0.0, descri…

# %%
# 动态配置调色工具 参数
sns.palplot(sns.cubehelix_palette(n_colors=8,start=3.0, rot=0.2, dark=0, light=.90, reverse=True))

# %%
# palette: 支持直接使用matplotlib色图名称
sns.barplot(x='size', y='total_bill', data=tips, palette='tab20')
# Out:
# <AxesSubplot:xlabel='size', ylabel='total_bill'>

# %% [markdown]
# ### Seaborn 配置色彩与样式 总结
# * set() 设置缺省样式与色彩
# * set_style('whitegrid')设置背景
#     * whith, dark, whitegrid, darkgrid, ticks
# * sns.despine(lift=True, bottom=True) 设置是否显示边线
# * sns.set_context('notebook') 根据场景需要设置字体、线粗细
#     * paper, notebook, talk, poster
# * sns.color_palette
#     * 使用 matplotlib 内置色图, 例如 tab20
#     * 自定义色彩列表: ['red', 'green', '#34495e', '#2ecc71']
# * 用一个颜色就能生成色图
#     * light_palette, dark_palette
# * 动态配置调色工具
#     * sns.choose_cubehelix_palette(as_comp=True)
#     * sns.cubehelix_palette

# %%
# Seaborn单变量分布图

# %%
# distplot: 用于观察数值变量的分布情况
# hist, kde, rug(地毯图) 的组合图

# pd.Series(np.random.randn(100)).plot.hist()
# pd.Series(np.random.randn(100)).plot.kde()
sns.rugplot(pd.Series(np.random.randn(100)))
# Out:
# <AxesSubplot:>

# %%
sns.set()
# rug : True 绘制rugplot地毯图
# hist,kde: True: 缺省
sns.distplot(pd.Series(np.random.randn(100)), rug=True)
# Out:
# <AxesSubplot:>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# color: 色彩 #cceecc red/green
sns.distplot(tips.total_bill, rug=True, color='r')
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
# hist bins 箱子数量
sns.distplot(tips.tip, bins=6)
# Out:
# <AxesSubplot:xlabel='tip'>

# %% [markdown]
# ### distplot 单变量分布图
# * hist/kde/rug 的组合
# * 用于观察单个变量的分布情况
# * 常用参数
#     * hist, kde, rug(True): 是否显示对应的图表
#     * bins 指定hist箱子数量

# %%
# kdeplot 和密度估计图
# 观察数据的分布特征, 是直方图hist的有益补充
# pd.Series(np.random.randn(100)).plot.kde()
sns.kdeplot(np.random.randn(100))
# Out:
# <AxesSubplot:>

# %%
# 二维核密度图 a = (x,y)
iris = sns.load_dataset('iris')
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
petal = iris[['petal_length', 'petal_width']]
# petal.plot.kde()
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# 根据鸢尾花品种分开数据, 分别绘制kde
petal_setosa = iris[iris.species=='setosa'][['petal_length', 'petal_width']]
petal_versicolor = iris[iris.species=='versicolor'][['petal_length', 'petal_width']]
petal_virginica = iris[iris.species=='virginica'][['petal_length', 'petal_width']]
# kdeplot 参数
# cmap: 色图配置
# shade: True 显示阴影
# shade_lowest: False 不显示白色(底色)
sns.kdeplot(petal_setosa, cmap='Blues', shade=True, shade_lowest=False)
sns.kdeplot(petal_virginica, cmap='Greens', shade=True, shade_lowest=False)
sns.kdeplot(petal_versicolor, cmap='Reds', shade=True, shade_lowest=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### kdeplot 核密度估计图 总结
# * 只管的观察数据的分布特征
# * 以为密度图与pandas kde 一样
# * 二维密度图可以观察 二维数据的分布 a=(x,y)
# * 常用参数
#     * shade: True 填充阴影
#     * shade_lowest: False 不显示白色

# %% [markdown]
# ## 双变量关系图
# 1. lineplot
# 2. scatterplot
# 3. heatmap
# 4. relplot
# 5. lmplot
# 6. jointplot与jointgrid
# 7. pairplot与pairgrid

# %%
# lineplot 线形图
# 回顾 pandas 线形图
tips[['total_bill', 'tip']].plot.line()
# Out:
# <AxesSubplot:>

# %%
# seaborn lineplot
# 线条: 均值
# 区域: 95%置信区间
# hue: 按色彩进行分组
sns.lineplot(x='day', y='total_bill', hue='smoker', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# 航班乘客数据集
flights = sns.load_dataset('flights')
flights.head()
# passengers 乘客数量
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.set_style('white') # white, dark, whitegrid, darkgrid, ticks
flights[flights.year == 1949].plot.line(x='month', y='passengers')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
# seaborn 绘制 lineplot
# 线条: 均值
# 区域: 95%(缺省)置信区间
# ci: None 不再绘制置信区间
# ci: 85 85%置信区间
sns.lineplot(x='year', y='passengers', data=flights, ci=None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.set()
# hue: 按色彩(指定的数据列)进行分组
sns.lineplot(x='year', y='passengers', data=flights, hue='month', palette='tab20')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### lineplot 线形图总结
# * 与pandas.plot.line类似,可以用于显示数据相对于时间的变化趋势
# * **特色**: 可以自动计算y轴数据的置信区间(默认值:95%)与平均值
# * **特色**: 可以分组hue绘制多个线形图
# * 常用参数
#     * x,y
#     * hue: 按色彩(指定的数据列)进行分组
#     * ci: 绘制置信区间
#         * 95(缺省值)
#         * None 不在绘制

# %%
# 散点图 pandas 回顾
tips.plot.scatter(x='total_bill', y='tip', c='red')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# heu: 色彩
# style: 散点绘制形状
# size: 散点大小
# sizes: 散点大小取值范围
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker', size='size', sizes=(20,200))
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# hue/style: 使用同一列数据时,绘制出的散点图更加清晰明白
sns.scatterplot(x='petal_length', y='petal_width', data=iris, hue='species', style='species')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# ### scatterplot 散点图总结
# * 用于观察两组数据之间的关系
# * 常用参数:
#     * x,y,data
#     * hue: 色彩分组绘制
#     * style: 散点绘制形状
#     * size: 散点大小
#     * sizes: 散点大小取值范围
#     * **特色**: hue/style: 使用同一列数据时,绘制出的散点图更加清晰明白

# %%
flights_table = flights.pivot(index='month', columns='year', values='passengers')
flights_table.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
# 绘制热力图 heatmap
sns.heatmap(flights_table)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
# heatmap 常用参数
# cmap 色图配置 https://matplotlib.org/examples/color/colormaps_reference.html
# annot: True 标注数值
# fmt : 标注数值格式 d : 整数, 0.2f : 浮点数保留小数点后两位数值
# linewidths : 线宽 0.5

# sns.heatmap( flights_table, cmap='Blues')

plt.figure(figsize=(12,6))
sns.heatmap( flights_table, cmap='Blues', annot=True, fmt='d', linewidths=0.5)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
car_crashes = sns.load_dataset('car_crashes')
car_crashes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
corr_matrix = car_crashes.corr()
corr_matrix
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(corr_matrix, annot=True, fmt='0.2f', cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
# 制作掩码
# 1 制作一个大小相同的矩阵, 设置值为 False
mask = np.zeros_like(corr_matrix, dtype=np.bool)
# 2 取出mask 掩码矩阵的上半部分的坐标值 np.triu_indices_from(mask)
# 3 将掩码矩阵对应的三班部分坐标的数据设置为 True
mask[np.triu_indices_from(mask)] = True
mask
# Out:
# array([[ True,  True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True],
#        [False, False, False, False, False,  True,  True],
#        [False, False, False, False, False, False,  True]])

# %%
# 利用掩码矩阵绘制热图
# mask 参数: 使用掩码矩阵
# cbar_kws 设置 colorbar,
# 配合cbar_kws设置vmax,vmin
plt.figure(figsize=(15,7))
sns.heatmap(corr_matrix, annot=True, fmt='0.2f', cmap='coolwarm', mask=mask,
           linewidths=0.2, cbar_kws={'ticks':[-1.0, -0.5, 0, 0.5, 1.0]}, vmax=1.0, vmin=-1.0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### heatmap 热力图 总结
# * **特色**: 热图使用色彩来表示数值
# * 常用于显示两个数值特征之间的关系, 并找出热点区域加以评估
# * 常用于显示相关矩阵 corr_matrix
#     * 使用 corr 方法生成 corr_matrix
#     * 制作 掩码矩阵 mask
#     * 绘制 热力图
# * 常用参数
#     * cmap 色图配置 **使用连续色图** https://matplotlib.org/examples/color/colormaps_reference.html
#     * annot : True 标注数值
#     * fmt : 标注数值格式 d : 整数, 0.2f 浮点数保留小数点后两位数字
#     * linewidths : 线宽 0.5
#     * cbar_kws, vmax, vmin : 设置 colorbar

# %%
# relplot 维度关系图
# 属于 FactGrid, 即基于维度分析特征之间的关系
# 可以绘制出基于不同维度的散点图 scatter 和线形图 line
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set()
sns.relplot(x='total_bill', y='tip', hue='sex', style='smoker', size='size', data=tips)

# %%
# col: 按列进行拆分
sns.relplot(x='total_bill', y='tip', hue='sex', col='smoker', size='size', data=tips)

# %%
# row: 按行拆分
sns.relplot(x='total_bill', y='tip', row='sex', col='smoker', size='size', data=tips)

# %%
# 一行代码查看所有7列数据之间的关系
sns.relplot(x='total_bill', y='tip', data=tips,
           col='day', row='time', hue='sex', style='smoker', size='size')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# col_wrap 换行
# kind : 图表类型 scatter(缺省), line
sns.relplot(x='year', y='passengers', col='month', col_wrap=4, data=flights, kind='line')

# %% [markdown]
# ### relplot 维度关系图 总结
# * 基于维度分析数据之间的关系
# * 可以绘制散点图和折线图
# * 常用参数
#     * x, y, data
#     * col : 列维度
#     * row : 行维度
#     * col_wrap : 换行
#     * kind : scatter(缺省), line

# %%
# lmplot 线性回归关系图
# 在散点图的基础上绘制一个线性回归趋势线, 用于判断x轴特征列与y轴目标值的关系趋势
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
# lmplot 也基于 FacetGrid
# col, row 维度参数
# hue 色彩分组
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', row='time', hue='smoker')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='size', y='total_bill', data=tips)

# %%
# x_jitter 将x轴数值随机摇摆 +-0.2
sns.lmplot(x='size', y='total_bill', data=tips, x_jitter=0.2)

# %% [markdown]
# ### lmplot 线性回归关系图 总结
# * 在散点图的基础上绘制一个线性回归趋势图, 用于判断x轴特征列与y轴目标值的关系趋势
# * 常用参数
#     * x, y, data
#     * col, row: 列、行维度分组
#     * hue: 色彩
#     * x_jitter: 将x轴数据随机晃动一个小范围的 +-0.2

# %% [markdown]
# ### jointplot 与 jointgrid
# * jointplot 组合分析图 同时绘制双变量关系图与单变量分布图
# * jointgrid 组合主阵图 比jointplot 更加灵活一些, 可以绘制的图表类型更加丰富

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
# kind 图表类型 scatter, reg, resid, kde, hex
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
# 同时绘制 一维、二维密度图
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
# jointgird
# plot方法: 两个图表类型 参数: 双变量关系图, 单变量分布图
p = sns.JointGrid(x='total_bill', y='tip', data=tips)
p.plot(sns.kdeplot, sns.distplot)

# %%
# plot_joint 绘制组合图
# plot_marginals 绘制边沿图
p = sns.JointGrid(x='total_bill', y='tip', data=tips)
p.plot_joint(sns.kdeplot, shade=True, shade_lowest=False)
p.plot_marginals(sns.distplot, rug=True)

# %% [markdown]
# ### jointplot 与 JointGrid 总结
# * jointplot 绘制分析图 同时绘制双变量关系图与单变量分布图
# * jointplot 同时绘制散点图与单变量分布图
# * jointplot 常用参数
#     * kind : "scatter" | "reg" | "resid" | "kde" | "hex"
#     * scatter, reg 常用
# * JointGrid 组合矩阵图 比jointplot 更加灵活一些, 可以绘制的图表类型更加丰富
# * JointGrid 常用参数
#     * plot 参数: 双变量关系图, 单变量分布图
#     * plot_joint 中心图表
#     * plot_marginals 边沿图表

# %%
# pairplot 散点矩阵图
sns.pairplot(iris)

# %%
# hue 色彩分组
sns.pairplot(iris, hue='species')

# %%
# markers 参数: 散点的样式
# diag_kind : hist, kde
# kiag_kws: 传递参数用于绘制diag图表
sns.pairplot(iris, hue='species', markers=['o', 'v', 's'], diag_kind='hist', diag_kws={'alpha':0.5})

# %%
# kind : scatter, reg
sns.pairplot(iris, kind='reg', hue='species')

# %%
# PairGrid
# map 方法 绘制散点图 不太常用
# map_diag 绘制对角线图
# map_offdiag 非对角线图
p = sns.PairGrid(iris)
p.map_offdiag(sns.scatterplot)
p.map_diag(sns.distplot)

# %%
# map_diag 绘制对角线图
# map_upper 绘制对角线上方的图表
# map_lower 绘制对角线下方的图表
# add_legend 加上图例说明
p = sns.PairGrid(iris, hue='species')
p.map_upper(sns.scatterplot)
p.map_diag(sns.distplot)
p.map_lower(sns.kdeplot)
p.add_legend()

# %% [markdown]
# ### pairplot 与 PairGrid 总结
# * 散点矩阵图: 绘制成对数据之间的关系
# * 常用绘制的图表名称:
#     * sns.scatterplot
#     * sns.kdeplot
#     * sns.distplot
# * pairplot 常用参数
#     * kind : scatter, reg
#     * markers 参数: 散点的样式
#     * diag_kind: hist, kde
#     * diag_kws: 传递参数用于绘制 diag 图表 alpha:0.5
# * PairGrid 绘制矩阵的map方法
#     * map 不常用
#     * map_offdiag 非对角线图表, map_diag 对角线图表
#     * map_upper 对角线上方图表, map_lower 对角线下方图表

# %% [markdown]
# ## 分类数据图

# %%
# Seaborn 内置数据集
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# swarmplot 群图
# 对比不同类别之间的数值差异与数值分布情况
